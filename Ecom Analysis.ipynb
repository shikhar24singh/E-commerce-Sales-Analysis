# %%
import pandas as pd
df = pd.read_csv("ecommerce_sales_analysis.csv")

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#      product_id  product_name        category   price  review_score  \
# 0             1     Product_1        Clothing  190.40           1.7
# 1             2     Product_2  Home & Kitchen  475.60           3.2
# 2             3     Product_3            Toys  367.34           4.5
# 3             4     Product_4            Toys  301.34           3.9
# 4             5     Product_5           Books   82.23           4.2
# ..          ...           ...             ...     ...           ...
# 995         996   Product_996  Home & Kitchen   50.33           3.6
# 996         997   Product_997  Home & Kitchen  459.07           4.8
# 997         998   Product_998          Sports   72.73           1.3
# 998         999   Product_999          Sports  475.37           1.2
# 999        1000  Product_1000            Toys  225.77           2.1
#
#      review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      1000 non-null   int64
#  1   product_name    1000 non-null   str
#  2   category        1000 non-null   str
#  3   price           1000 non-null   float64
#  4   review_score    1000 non-null   float64
#  5   review_count    1000 non-null   int64
#  6   sales_month_1   1000 non-null   int64
#  7   sales_month_2   1000 non-null   int64
#  8   sales_month_3   1000 non-null   int64
#  9   sales_month_4   1000 non-null   int64
#  10  sales_month_5   1000 non-null   int64
#  11  sales_month_6   1000 non-null   int64
#  12  sales_month_7   1000 non-null   int64
#  13  sales_month_8   1000 non-null   int64
#  14  sales_month_9   1000 non-null   int64
#  15  sales_month_10  1000 non-null   int64
#  16  sales_month_11  1000 non-null   int64
# ...

# %%
df.head()
# Out:
#    product_id product_name        category   price  review_score  \
# 0           1    Product_1        Clothing  190.40           1.7
# 1           2    Product_2  Home & Kitchen  475.60           3.2
# 2           3    Product_3            Toys  367.34           4.5
# 3           4    Product_4            Toys  301.34           3.9
# 4           5    Product_5           Books   82.23           4.2
#
#    review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220            479            449             92            784
# 1           903             21            989            861            863
# 2           163            348            558            567            143
# 3           951            725            678             59             15
# 4           220            682            451            649            301
#
#    sales_month_5  sales_month_6  sales_month_7  sales_month_8  sales_month_9  \
# ...

# %%
df.isnull().sum()
# Out:
# product_id        0
# product_name      0
# category          0
# price             0
# review_score      0
# review_count      0
# sales_month_1     0
# sales_month_2     0
# sales_month_3     0
# sales_month_4     0
# sales_month_5     0
# sales_month_6     0
# sales_month_7     0
# sales_month_8     0
# sales_month_9     0
# sales_month_10    0
# sales_month_11    0
# sales_month_12    0
# dtype: int64

# %%
df['category'].unique()
# Out:
# <StringArray>
# [      'Clothing', 'Home & Kitchen',           'Toys',          'Books',
#     'Electronics',         'Health',         'Sports']
# Length: 7, dtype: str

# %%
df.describe().T
# Out:
#                  count       mean         std   min     25%     50%      75%  \
# product_id      1000.0  500.50000  288.819436  1.00  250.75  500.50  750.250
# price           1000.0  247.67713  144.607983  7.29  121.81  250.92  373.435
# review_score    1000.0    3.02760    1.171243  1.00    2.00    3.10    4.000
# review_count    1000.0  526.50600  282.269932  1.00  283.75  543.00  772.000
# sales_month_1   1000.0  498.30600  289.941478  0.00  245.50  507.50  740.750
# sales_month_2   1000.0  507.66100  285.992689  2.00  262.50  508.00  756.250
# sales_month_3   1000.0  506.73900  294.010873  0.00  243.75  493.00  777.250
# sales_month_4   1000.0  503.82300  286.645567  0.00  261.50  501.50  749.500
# sales_month_5   1000.0  487.19400  287.844324  0.00  221.00  497.00  727.000
# sales_month_6   1000.0  491.65300  289.234018  0.00  236.00  479.50  740.500
# sales_month_7   1000.0  507.01100  291.047287  0.00  254.00  522.50  757.250
# ...

# %%
df.describe()
# Out:
#         product_id        price  review_score  review_count  sales_month_1  \
# count  1000.000000  1000.000000   1000.000000   1000.000000    1000.000000
# mean    500.500000   247.677130      3.027600    526.506000     498.306000
# std     288.819436   144.607983      1.171243    282.269932     289.941478
# min       1.000000     7.290000      1.000000      1.000000       0.000000
# 25%     250.750000   121.810000      2.000000    283.750000     245.500000
# 50%     500.500000   250.920000      3.100000    543.000000     507.500000
# 75%     750.250000   373.435000      4.000000    772.000000     740.750000
# max    1000.000000   499.860000      5.000000    999.000000    1000.000000
#
#        sales_month_2  sales_month_3  sales_month_4  sales_month_5  \
# count    1000.000000    1000.000000    1000.000000    1000.000000
# mean      507.661000     506.739000     503.823000     487.194000
# std       285.992689     294.010873     286.645567     287.844324
# ...

# %%
features = ["price","review_score","review_count","sales_month_1","sales_month_2","sales_month_3","sales_month_4","sales_month_5","sales_month_6", "sales_month_7","sales_month_8","sales_month_9","sales_month_10","sales_month_11","sales_month_12"]
plt.figure(figsize = (12,5), dpi = 300)
plt.title("To show if there are any outliers present")
plt.xlabel("Features")
plt.ylabel("count of happens")
plt.boxplot(df[features])
plt.legend(title = "outliers")
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_11192\1806283257.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title = "outliers")

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["total_sales"] = df.loc[:, "sales_month_1" : "sales_month_12"].sum(axis = 1)
df.tail(10)
# Out:
#      product_id  product_name        category   price  review_score  \
# 990         991   Product_991            Toys  400.71           4.1
# 991         992   Product_992  Home & Kitchen  348.87           1.6
# 992         993   Product_993  Home & Kitchen  139.71           3.4
# 993         994   Product_994  Home & Kitchen  297.16           1.5
# 994         995   Product_995          Sports  183.68           4.0
# 995         996   Product_996  Home & Kitchen   50.33           3.6
# 996         997   Product_997  Home & Kitchen  459.07           4.8
# 997         998   Product_998          Sports   72.73           1.3
# 998         999   Product_999          Sports  475.37           1.2
# 999        1000  Product_1000            Toys  225.77           2.1
#
#      review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 990           323             58            583            180            888
# ...

# %%
from sqlalchemy import create_engine
username = "postgres"
password = "shikharsingh2004"
host = "localhost"
port = "5432"
database = "ecom_analysis"

engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}')
table_name = "sales"
df.to_sql(table_name, engine, if_exists = "replace", index = False)
# Out:
# 1000

# %%
df['total_revenue'] = df['price'] * df['total_sales']

# %%
df.head()
# Out:
#    product_id product_name        category   price  review_score  \
# 0           1    Product_1        Clothing  190.40           1.7
# 1           2    Product_2  Home & Kitchen  475.60           3.2
# 2           3    Product_3            Toys  367.34           4.5
# 3           4    Product_4            Toys  301.34           3.9
# 4           5    Product_5           Books   82.23           4.2
#
#    review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220            479            449             92            784
# 1           903             21            989            861            863
# 2           163            348            558            567            143
# 3           951            725            678             59             15
# 4           220            682            451            649            301
#
#    sales_month_5  sales_month_6  sales_month_7  sales_month_8  sales_month_9  \
# ...

# %%
df.to_sql(table_name, engine, if_exists = "replace", index = False)
# Out:
# 1000
